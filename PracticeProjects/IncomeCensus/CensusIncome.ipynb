# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
Census=pd.read_csv('D:/FilpRobo/census_income.csv')

# %%
Census
# Out:
#        Age         Workclass  Fnlwgt   Education  Education_num  \
# 0       50  Self-emp-not-inc   83311   Bachelors             13
# 1       38           Private  215646     HS-grad              9
# 2       53           Private  234721        11th              7
# 3       28           Private  338409   Bachelors             13
# 4       37           Private  284582     Masters             14
# ...    ...               ...     ...         ...            ...
# 32555   27           Private  257302  Assoc-acdm             12
# 32556   40           Private  154374     HS-grad              9
# 32557   58           Private  151910     HS-grad              9
# 32558   22           Private  201490     HS-grad              9
# 32559   52      Self-emp-inc  287927     HS-grad              9
#
#            Marital_status         Occupation   Relationship   Race     Sex  \
# 0      Married-civ-spouse    Exec-managerial        Husband  White    Male
# ...

# %%
Census.shape
# Out:
# (32560, 15)

# %%
Census.dtypes
# Out:
# Age                int64
# Workclass         object
# Fnlwgt             int64
# Education         object
# Education_num      int64
# Marital_status    object
# Occupation        object
# Relationship      object
# Race              object
# Sex               object
# Capital_gain       int64
# Capital_loss       int64
# Hours_per_week     int64
# Native_country    object
# Income            object
# dtype: object

# %%
Census.isna().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %%
Census['Workclass'].value_counts()
# Out:
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# ?                    1836
# State-gov            1297
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: Workclass, dtype: int64

# %%
Census['Occupation'].value_counts()
# Out:
# Prof-specialty       4140
# Craft-repair         4099
# Exec-managerial      4066
# Adm-clerical         3769
# Sales                3650
# Other-service        3295
# Machine-op-inspct    2002
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1370
# Farming-fishing       994
# Tech-support          928
# Protective-serv       649
# Priv-house-serv       149
# Armed-Forces            9
# Name: Occupation, dtype: int64

# %%
Census['Native_country'].value_counts()
# Out:
# United-States                 29169
# Mexico                          643
# ?                               583
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Guatemala                        64
# Japan                            62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# ...

# %%
Census.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %%
sns.countplot(Census['Income'],hue='Relationship',data=Census)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='Income', ylabel='count'>

# %%
Census['Workclass']=Census['Workclass'].replace('?','Private')

# %%
Census['Workclass'].value_counts()
# Out:
# Private             24532
# Self-emp-not-inc     2541
# Local-gov            2093
# State-gov            1297
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: Workclass, dtype: int64

# %%
Census['Occupation']=Census['Occupation'].replace('?','Prof-specialty')

# %%
Census['Occupation'].value_counts()
# Out:
# Prof-specialty       5983
# Craft-repair         4099
# Exec-managerial      4066
# Adm-clerical         3769
# Sales                3650
# Other-service        3295
# Machine-op-inspct    2002
# Transport-moving     1597
# Handlers-cleaners    1370
# Farming-fishing       994
# Tech-support          928
# Protective-serv       649
# Priv-house-serv       149
# Armed-Forces            9
# Name: Occupation, dtype: int64

# %%
Census['Native_country']=Census['Native_country'].replace('?','United-States')

# %%
Census['Native_country'].value_counts()
# Out:
# United-States                 29752
# Mexico                          643
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Guatemala                        64
# Japan                            62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# Peru                             31
# ...

# %%
Census['Education'].value_counts()
# Out:
# HS-grad         10501
# Some-college     7291
# Bachelors        5354
# Masters          1723
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: Education, dtype: int64

# %%
Census['Education']=Census['Education'].replace(['Preschool','1st-4th','5th-6th','12th','9th','7th-8th','10th','11th'],'School')

# %%
Census['Education']=Census['Education'].replace(['HS-grad'],'High-School')
Census['Education']=Census['Education'].replace(['Assoc-voc','Assoc-acdm','Prof-school','Some-college'],'Higher')

# %%
Census['Education'].value_counts()
# Out:
# High-School    10501
# Higher         10316
# Bachelors       5354
# School          4253
# Masters         1723
# Doctorate        413
# Name: Education, dtype: int64

# %%
Census['Income']=Census['Income'].replace({'<=50K':0,'>50K':1})

# %%
Census['Income'].value_counts()
# Out:
# 0    24719
# 1     7841
# Name: Income, dtype: int64

# %%
Census['Marital_status'].value_counts()
# Out:
# Married-civ-spouse       14976
# Never-married            10682
# Divorced                  4443
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: Marital_status, dtype: int64

# %%
Census['Marital_status']=Census['Marital_status'].replace(['Married-civ-spouse','Married-AF-spouse'],'Married')
Census['Marital_status']=Census['Marital_status'].replace(['Divorced','Widowed','Separated','Married-spouse-absent'],'Others')

# %%
Census['Marital_status'].value_counts()
# Out:
# Married          14999
# Never-married    10682
# Others            6879
# Name: Marital_status, dtype: int64

# %%
Census.corr()
# Out:
#                      Age    Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# Age             1.000000 -0.076646       0.036527      0.077674      0.057775
# Fnlwgt         -0.076646  1.000000      -0.043159      0.000437     -0.010259
# Education_num   0.036527 -0.043159       1.000000      0.122627      0.079932
# Capital_gain    0.077674  0.000437       0.122627      1.000000     -0.031614
# Capital_loss    0.057775 -0.010259       0.079932     -0.031614      1.000000
# Hours_per_week  0.068756 -0.018770       0.148127      0.078409      0.054256
# Income          0.234039 -0.009481       0.335182      0.223333      0.150523
#
#                 Hours_per_week    Income
# Age                   0.068756  0.234039
# Fnlwgt               -0.018770 -0.009481
# Education_num         0.148127  0.335182
# Capital_gain          0.078409  0.223333
# Capital_loss          0.054256  0.150523
# Hours_per_week        1.000000  0.229690
# Income                0.229690  1.000000

# %%
sns.heatmap(Census.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
Census.hist(figsize=(12,12),layout=(3,3),sharex=False)
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Fnlwgt'}>,
#         <AxesSubplot:title={'center':'Education_num'}>],
#        [<AxesSubplot:title={'center':'Capital_gain'}>,
#         <AxesSubplot:title={'center':'Capital_loss'}>,
#         <AxesSubplot:title={'center':'Hours_per_week'}>],
#        [<AxesSubplot:title={'center':'Income'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
Census.plot(kind='box',figsize=(12,12),layout=(3,3),sharex=False,subplots=True)
# Out:
# Age                  AxesSubplot(0.125,0.657941;0.227941x0.222059)
# Fnlwgt            AxesSubplot(0.398529,0.657941;0.227941x0.222059)
# Education_num     AxesSubplot(0.672059,0.657941;0.227941x0.222059)
# Capital_gain         AxesSubplot(0.125,0.391471;0.227941x0.222059)
# Capital_loss      AxesSubplot(0.398529,0.391471;0.227941x0.222059)
# Hours_per_week    AxesSubplot(0.672059,0.391471;0.227941x0.222059)
# Income                  AxesSubplot(0.125,0.125;0.227941x0.222059)
# dtype: object

# %%
px.pie(Census,values='Education_num',names='Education',title='% of edu',color_discrete_sequence=px.colors.qualitative.T10)
# Out:
# <div>                            <div id="c6c0fdb1-3463-43ac-8ad6-b6e7a18595cd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c6c0fdb1-3463-43ac-8ad6-b6e7a18595cd")) {                    Plotly.newPlot(                        "c6c0fdb1-3463-43ac-8ad6-b6e7a18595cd",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Education=%{label}<br>Education_num=%{value}<extra></extra>","labels":["Bachelors","High-School","School","Bachelors","Masters","School","High-School","Masters","Bachelors","Higher","Bachelors","Bachelors","Higher","Higher","School","High-School","High-School","School","Masters","Doctorate","High-School","School","School","High-School","Bachelors","High-School","Higher","High-School","High-School","Higher",
# ...

# %%
sns.countplot(Census['Race'],hue='Income',data=Census)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='Race', ylabel='count'>

# %%
sns.countplot(Census['Occupation'],hue='Income',data=Census)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='Occupation', ylabel='count'>

# %%
sns.countplot(Census['Education'],hue='Sex',data=Census)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='Education', ylabel='count'>

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %%
census=Census.copy()
census=census.apply(LabelEncoder().fit_transform)
census.head()
# Out:
#    Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0   33          5    2925          0             12               0
# 1   21          3   14085          2              8               2
# 2   36          3   15335          5              6               0
# 3   11          3   19354          0             12               0
# 4   20          3   17699          4             13               0
#
#    Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# 0           3             0     4    1             0             0
# 1           5             1     4    1             0             0
# 2           5             0     2    1             0             0
# 3           9             5     2    0             0             0
# 4           3             5     4    0             0             0
#
#    Hours_per_week  Native_country  Income
# 0              12              38       0
# 1              39              38       0
# ...

# %%
census
# Out:
#        Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0       33          5    2925          0             12               0
# 1       21          3   14085          2              8               2
# 2       36          3   15335          5              6               0
# 3       11          3   19354          0             12               0
# 4       20          3   17699          4             13               0
# ...    ...        ...     ...        ...            ...             ...
# 32555   10          3   16527          3             11               0
# 32556   23          3    8079          2              8               0
# 32557   41          3    7882          2              8               2
# 32558    5          3   12880          2              8               1
# 32559   35          4   17824          2              8               0
#
#        Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# ...

# %%
census['Workclass'].value_counts()
# Out:
# 3    24532
# 5     2541
# 1     2093
# 6     1297
# 4     1116
# 0      960
# 7       14
# 2        7
# Name: Workclass, dtype: int64

# %%
SSLR=StandardScaler().fit(census.drop('Income',axis=1))

# %%
X=census.drop('Income',axis=1)
y=census['Income']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=40)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

L=LogisticRegression()

# %%
L
# Out:
# LogisticRegression()

# %%
model=L.fit(X_train,y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression

# %%
format(L.score(X_train,y_train))
# Out:
# '0.7899262899262899'

# %%
format(L.score(X_test,y_test))
# Out:
# '0.7903357903357904'

# %%
from sklearn.ensemble import RandomForestClassifier
RF=RandomForestClassifier()
model1=RF.fit(X_train,y_train)
prediction1=model1.predict(X_test)

# %%
print(format(RF.score(X_train,y_train)))
# Out:
# 0.999956124956125

# %%
format(RF.score(X_test,y_test))
# Out:
# '0.8594389844389845'

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
confusion_matrix(y_test,prediction1)
# Out:
# array([[6915,  497],
#        [ 876, 1480]], dtype=int64)

# %%
classification_report(y_test,prediction1)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.89      0.93      0.91      7412\n           1       0.75      0.63      0.68      2356\n\n    accuracy                           0.86      9768\n   macro avg       0.82      0.78      0.80      9768\nweighted avg       0.85      0.86      0.86      9768\n'

# %%
print(6915/(6915+876))
# Out:
# 0.8875625721986908

# %%
print(6915/(6915+497))
# Out:
# 0.9329465731246627

# %%
print("precision=",1480/(1480+497))
# Out:
# precision= 0.7486090035407182

# %%
print("Recall=",1480/(1480+876))
# Out:
# Recall= 0.6281833616298812
