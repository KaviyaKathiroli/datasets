# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('darkgrid')
plt.rcParams['font.size']=15
plt.rcParams['figure.figsize']=(10,7)
plt.rcParams['figure.facecolor']='#FFE5b4'
data_set=pd.read_csv('D:\\FilpRobo\\happiness_score_dataset.csv')

# %%
data_set.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %%
data_columns=['Country','Region','Happiness Score','Economy (GDP per Capita)','Health (Life Expectancy)','Freedom','Trust (Government Corruption)','Generosity','Dystopia Residual']

# %%
data_columns
# Out:
# ['Country',
#  'Region',
#  'Happiness Score',
#  'Economy (GDP per Capita)',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Trust (Government Corruption)',
#  'Generosity',
#  'Dystopia Residual']

# %%
data_set=data_set[data_columns].copy()

# %%
data_set
# Out:
#          Country                           Region  Happiness Score  \
# 0    Switzerland                   Western Europe            7.587
# 1        Iceland                   Western Europe            7.561
# 2        Denmark                   Western Europe            7.527
# 3         Norway                   Western Europe            7.522
# 4         Canada                    North America            7.427
# ..           ...                              ...              ...
# 153       Rwanda               Sub-Saharan Africa            3.465
# 154        Benin               Sub-Saharan Africa            3.340
# 155        Syria  Middle East and Northern Africa            3.006
# 156      Burundi               Sub-Saharan Africa            2.905
# 157         Togo               Sub-Saharan Africa            2.839
#
#      Economy (GDP per Capita)  Health (Life Expectancy)  Freedom  \
# 0                     1.39651                   0.94143  0.66557
# 1                     1.30232                   0.94784  0.62877
# 2                     1.32548                   0.87464  0.64938
# 3                     1.45900                   0.88521  0.66973
# 4                     1.32629                   0.90563  0.63297
# ..                        ...                       ...      ...
# 153                   0.22208                   0.42864  0.59201
# 154                   0.28665                   0.31910  0.48450
# 155                   0.66320                   0.72193  0.15684
# 156                   0.01530                   0.22396  0.11850
# 157                   0.20868                   0.28443  0.36453
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                          0.41978     0.29678            2.51738
# 1                          0.14145     0.43630            2.70201
# 2                          0.48357     0.34139            2.49204
# 3                          0.36503     0.34699            2.46531
# 4                          0.32957     0.45811            2.45176
# ..                             ...         ...                ...
# 153                        0.55191     0.22628            0.67042
# 154                        0.08010     0.18260            1.63328
# 155                        0.18906     0.47179            0.32858
# 156                        0.10062     0.19727            1.83302
# 157                        0.10731     0.16681            1.56726
#
# [158 rows x 9 columns]

# %%
data_set.rename(columns={'Country':'country','Region':'RegInd','Happiness Score':'HappyScore','Economy (GDP per Capita)':'LGDP','Health (Life Expectancy)':'HealthylifeExp','Freedom':'FreedomlifeChoices','Trust (Government Corruption)':'PerceptionCorruption','Generosity':'generosity','Dystopia Residual':'Dystopia'},inplace=True)

# %%
data_set.head()
# Out:
#        country          RegInd  HappyScore     LGDP  HealthylifeExp  \
# 0  Switzerland  Western Europe       7.587  1.39651         0.94143
# 1      Iceland  Western Europe       7.561  1.30232         0.94784
# 2      Denmark  Western Europe       7.527  1.32548         0.87464
# 3       Norway  Western Europe       7.522  1.45900         0.88521
# 4       Canada   North America       7.427  1.32629         0.90563
#
#    FreedomlifeChoices  PerceptionCorruption  generosity  Dystopia
# 0             0.66557               0.41978     0.29678   2.51738
# 1             0.62877               0.14145     0.43630   2.70201
# 2             0.64938               0.48357     0.34139   2.49204
# 3             0.66973               0.36503     0.34699   2.46531
# 4             0.63297               0.32957     0.45811   2.45176

# %%
data_set.isnull().sum()
# Out:
# country                 0
# RegInd                  0
# HappyScore              0
# LGDP                    0
# HealthylifeExp          0
# FreedomlifeChoices      0
# PerceptionCorruption    0
# generosity              0
# Dystopia                0
# dtype: int64

# %%
#happy vs GDP
#plt.recParams['figure'.'figsize']=(15,7)
plt.title('Plot HappyScore Vs GDP')
sns.scatterplot(x=data_set.HappyScore,y=data_set.LGDP,hue=data_set.RegInd);
plt.legend(loc='upper left',fontsize='10')
plt.xlabel('Happy Score')
plt.ylabel('GDP per Capita')
# Out:
# Text(0, 0.5, 'GDP per Capita')

# %%
gdp_region=data_set.groupby('RegInd')['LGDP'].sum()

# %%
gdp_region
# Out:
# RegInd
# Australia and New Zealand           2.58376
# Central and Eastern Europe         27.33071
# Eastern Asia                        6.91068
# Latin America and Caribbean        19.28994
# Middle East and Northern Africa    21.33947
# North America                       2.72080
# Southeastern Asia                   7.10149
# Southern Asia                       3.92340
# Sub-Saharan Africa                 15.21892
# Western Europe                     27.27051
# Name: LGDP, dtype: float64

# %%
gdp_region.plot.pie(autopct='%1.1f%%')
plt.title('GDP per rigion')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
tot_count=data_set.groupby('RegInd')[['country']].count()
tot_count
# Out:
#                                  country
# RegInd
# Australia and New Zealand              2
# Central and Eastern Europe            29
# Eastern Asia                           6
# Latin America and Caribbean           22
# Middle East and Northern Africa       20
# North America                          2
# Southeastern Asia                      9
# Southern Asia                          7
# Sub-Saharan Africa                    40
# Western Europe                        21

# %%
##corelation Map
cor=data_set.corr(method="pearson")
f,ax=plt.subplots(figsize=(10,5))
sns.heatmap(cor,mask=np.zeros_like(cor,dtype=np.bool),cmap="Blues",square=True, ax=ax)
# Out:
# C:\Users\smile\AppData\Local\Temp/ipykernel_18068/361872036.py:4: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   sns.heatmap(cor,mask=np.zeros_like(cor,dtype=np.bool),cmap="Blues",square=True, ax=ax)
# <AxesSubplot:>

# %%
##corruption in different regions
corruption=data_set.groupby('RegInd')[['PerceptionCorruption']].mean()

# %%
corruption
# Out:
#                                  PerceptionCorruption
# RegInd
# Australia and New Zealand                    0.392795
# Central and Eastern Europe                   0.086674
# Eastern Asia                                 0.127695
# Latin America and Caribbean                  0.117172
# Middle East and Northern Africa              0.181702
# North America                                0.244235
# Southeastern Asia                            0.151276
# Southern Asia                                0.102536
# Sub-Saharan Africa                           0.123878
# Western Europe                               0.231463

# %%
plt.rcParams['figure.figsize']=(12,8)
plt.title('Perception of Corruption')
plt.xlabel('Regions',fontsize=15)
plt.ylabel('Corruption Index',fontsize=15)
plt.xticks(rotation=30,ha='right')
plt.bar(corruption.index,corruption.PerceptionCorruption)
# Out:
# <BarContainer object of 10 artists>

# %%
top10=data_set.head(10)
bottom10=data_set.tail(10)
bottom10
# Out:
#           country                           RegInd  HappyScore     LGDP  \
# 148          Chad               Sub-Saharan Africa       3.667  0.34193
# 149        Guinea               Sub-Saharan Africa       3.656  0.17417
# 150   Ivory Coast               Sub-Saharan Africa       3.655  0.46534
# 151  Burkina Faso               Sub-Saharan Africa       3.587  0.25812
# 152   Afghanistan                    Southern Asia       3.575  0.31982
# 153        Rwanda               Sub-Saharan Africa       3.465  0.22208
# 154         Benin               Sub-Saharan Africa       3.340  0.28665
# 155         Syria  Middle East and Northern Africa       3.006  0.66320
# 156       Burundi               Sub-Saharan Africa       2.905  0.01530
# 157          Togo               Sub-Saharan Africa       2.839  0.20868
#
#      HealthylifeExp  FreedomlifeChoices  PerceptionCorruption  generosity  \
# 148         0.15010             0.23501               0.05269     0.18386
# 149         0.24009             0.37725               0.12139     0.28657
# 150         0.15185             0.46866               0.17922     0.20165
# 151         0.27125             0.39493               0.12832     0.21747
# 152         0.30335             0.23414               0.09719     0.36510
# 153         0.42864             0.59201               0.55191     0.22628
# 154         0.31910             0.48450               0.08010     0.18260
# 155         0.72193             0.15684               0.18906     0.47179
# 156         0.22396             0.11850               0.10062     0.19727
# 157         0.28443             0.36453               0.10731     0.16681
#
#      Dystopia
# 148   1.94296
# 149   1.99172
# 150   1.41723
# 151   1.46494
# 152   1.95210
# 153   0.67042
# 154   1.63328
# 155   0.32858
# 156   1.83302
# 157   1.56726

# %%
fig, axes=plt.subplots(1,2, figsize=(16,6))
plt.tight_layout(pad=2)
xlabels=top10.country
axes[0].set_title('Top 10 Countries Life Expentency')
axes[0].set_xticklabels(xlabels,rotation=45,ha='right')
sns.barplot(x=top10.country,y=top10.HealthylifeExp, ax=axes[0])
axes[0].set_xlabel('Country')
axes[0].set_ylabel('Life Expentency')

xlabels=bottom10.country
axes[1].set_title('Bottom 10 Countries Life Expentency')
axes[1].set_xticklabels(xlabels,rotation=45,ha='right')
sns.barplot(x=bottom10.country,y=bottom10.HealthylifeExp, ax=axes[1])
axes[1].set_xlabel('Country')
axes[1].set_ylabel('Life Expentency')
# Out:
# C:\Users\smile\AppData\Local\Temp/ipykernel_18068/1211229907.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[0].set_xticklabels(xlabels,rotation=45,ha='right')
# C:\Users\smile\AppData\Local\Temp/ipykernel_18068/1211229907.py:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[1].set_xticklabels(xlabels,rotation=45,ha='right')
# Text(599.1068181818181, 0.5, 'Life Expentency')

# %%
plt.rcParams['figure.figsize']=(15,7)
sns.scatterplot(x=data_set.FreedomlifeChoices, y=data_set.HappyScore, hue=data_set.RegInd , s=200)
plt.legend(loc='upper left',fontsize='12')
plt.xlabel('Freedom of making Life choices')
plt.ylabel('Happiness Score')
# Out:
# Text(0, 0.5, 'Happiness Score')

# %%
top10corruption=data_set.sort_values(by='PerceptionCorruption').head(10)
top10corruption
# Out:
#                     country                       RegInd  HappyScore     LGDP  \
# 73                Indonesia            Southeastern Asia       5.399  0.82827
# 95   Bosnia and Herzegovina   Central and Eastern Europe       4.949  0.83223
# 85                  Romania   Central and Eastern Europe       5.124  1.04345
# 133                Bulgaria   Central and Eastern Europe       4.218  1.01216
# 55                Lithuania   Central and Eastern Europe       5.833  1.14723
# 87                 Portugal               Western Europe       5.102  1.15991
# 40      Trinidad and Tobago  Latin America and Caribbean       6.168  1.21183
# 101                  Greece               Western Europe       4.857  1.15406
# 51                  Moldova   Central and Eastern Europe       5.889  0.59448
# 64                  Jamaica  Latin America and Caribbean       5.709  0.81038
#
#      HealthylifeExp  FreedomlifeChoices  PerceptionCorruption  generosity  \
# 73          0.63793             0.46611               0.00000     0.51535
# 95          0.79081             0.09245               0.00227     0.24808
# 85          0.76890             0.35068               0.00649     0.13748
# 133         0.76649             0.30587               0.00872     0.11921
# 55          0.73128             0.21342               0.01031     0.02641
# 87          0.87519             0.51469               0.01078     0.13719
# 40          0.61483             0.55884               0.01140     0.31844
# 101         0.88213             0.07699               0.01397     0.00000
# 51          0.61826             0.32818               0.01615     0.20951
# 64          0.68741             0.50442               0.02299     0.21230
#
#      Dystopia
# 73    1.86399
# 95    2.06367
# 85    1.93129
# 133   0.89991
# 55    2.44649
# 87    1.26462
# 40    2.26882
# 101   1.80101
# 51    3.10712
# 64    2.32038

# %%
plt.rcParams['figure.figsize']=(12,6)
plt.title('Countries of perception of corruption')
plt.xlabel('top10corruption',fontsize=14)
plt.ylabel('Corruption Index',fontsize=14)
plt.xticks(rotation=30, ha='right')
plt.bar(top10corruption.country,top10corruption.PerceptionCorruption)
# Out:
# <BarContainer object of 10 artists>

# %%
##corruption vs happiness
plt.rcParams['figure.figsize']=(15,7)
sns.scatterplot(x=data_set.HappyScore,y=data_set.PerceptionCorruption, hue=data_set.RegInd, s=200)
plt.legend(loc='lower left',fontsize='16')
plt.xlabel('Happiness Score')
plt.ylabel('Corruption')
# Out:
# Text(0, 0.5, 'Corruption')
